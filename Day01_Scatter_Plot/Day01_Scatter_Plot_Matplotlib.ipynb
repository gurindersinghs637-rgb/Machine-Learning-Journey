# %%
#                                             MACHINE LEARNING JOUORNEY

# %%
#SCATTER PLOT:

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
x=np.array([2,3,4,5,3,5,4,7,5,3,23,2,43,4,5,45,4,55,4,65,99,55])
y=np.array([3,4,5,6,6,7,8,23,45,32,54,2,4,24,24,45,6,65,4,3,3,4])
plt.scatter(x,y)

# %%
x=np.array([2,3,4,5,3,5,4,7,5,3,23,2,43,4,5,45,4,55,4,65,99,55])
y=np.array([3,4,5,6,6,7,8,23,45,32,54,2,4,24,24,45,6,65,4,3,3,4])
plt.scatter(x,y,color="green") # give a color off a dots

# %%
x=np.array([2,3,4,5,3,5,4,7,5,3,23,2,43,4,5,45,4,55,4,65,99,55])
y=np.array([3,4,5,6,6,7,8,23,45,32,54,2,4,24,24,45,6,65,4,3,3,4])
plt.scatter(x,y,color="red")
x = np.array([2,31,4,5,3,5,43,7,51,3,23,2,43,48,5,45,40,55,42,65,99,55])
y = np.array([3,4,5,61,6,7,8,23,45,32,54,2,46,24,24,45,36,65,14,3,3,4])
plt.scatter(x,y,color="green")

# %%
x = np.array([2,31,4,5,3,5,43,])
y = np.array([3,4,5,31,6,7,8,])
colors=("red","green","yellow","black","brown","pink","grey") # different colors using colors
plt.scatter(x,y,c=colors)

# %%
x = np.array([2,3,4,5,6,7,8])
y = np.array([3,4,5,31,6,7,8])
colors=np.array([3,4,5,9,6,7,8,]) # we can also give this colors using np array
plt.scatter(x,y,c=colors)

# %%
x = np.array([2,3,4,5,6,7,8])
y = np.array([3,4,5,31,6,7,8])
colors=np.array([3,4,5,9,6,7,8])
plt.scatter(x,y,c=colors,cmap="plasma")
plt.colorbar()

# %%
from matplotlib import colorbar
print(colorbar)
# Out:
# <module 'matplotlib.colorbar' from '/usr/local/lib/python3.12/dist-packages/matplotlib/colorbar.py'>

# %%
x = np.array([2,3,4,5,6,7,8])
y = np.array([3,4,5,31,6,7,8])
colors=np.array([3,4,5,9,6,7,8])
sizes=np.array([32,33,243,140,45,65,44])
plt.scatter(x,y,c=colors,cmap="plasma",s=sizes)
plt.colorbar()

# %%
x = np.random.randint(100, size=(100))
y = np.random.randint(100, size=(100))
colors = np.random.randint(100, size=(100))
sizes = 5 * np.random.randint(100, size=(100))
plt.scatter(x, y, c=colors, cmap="nipy_spectral", s=sizes, alpha=0.3)
plt.colorbar(label="Color Scale")
plt.show()

# %%
x=np.array(["A","C","B","E"])
y=np.array([12,13,14,15])
colors=["red","blue","pink","brown"]
plt.bar(x,y,color=colors)
# Out:
# <BarContainer object of 4 artists>

# %%
x=np.array(["A","C","B","E"])
y=np.array([12,13,14,15])
colors=["red","blue","pink","brown"]
plt.barh(x,y,color=colors)
# Out:
# <BarContainer object of 4 artists>

# %%
x=np.array(["A","C","B","E"])
y=np.array([12,13,14,15])
colors=["red","blue","pink","brown"]
plt.bar(x,y,color=colors,width=0.2)
# Out:
# <BarContainer object of 4 artists>

# %%
x=np.array(["A","C","B","E"])
y=np.array([12,13,14,15])
colors=["red","blue","pink","brown"]
plt.barh(x,y,color=colors,height=0.2)
# Out:
# <BarContainer object of 4 artists>

# %%
x=np.array([12,13,14,15])
plt.pie(x)
# Out:
# ([<matplotlib.patches.Wedge at 0x7f915d4335f0>,
# ...
#  [Text(0.8426488596463491, 0.7070664037675015, ''),
#   Text(-0.6044599917942917, 0.9190365163148008, ''),
#   Text(-0.9190365619502578, -0.6044599224089634, ''),
#   Text(0.7070662631386209, -0.8426489776479805, '')])

# %%
x=np.array([12,13,14,15])
labels=(["A","C","B","E"])
plt.pie(x,labels=labels)
# Out:
# ([<matplotlib.patches.Wedge at 0x7f915d007230>,
# ...
#  [Text(0.8426488596463491, 0.7070664037675015, 'A'),
#   Text(-0.6044599917942917, 0.9190365163148008, 'C'),
#   Text(-0.9190365619502578, -0.6044599224089634, 'B'),
#   Text(0.7070662631386209, -0.8426489776479805, 'E')])

# %%
x=np.array([12,13,14,15])
labels=(["A","C","B","E"])
myexplode=[0.4,0,0.6,0]
plt.pie(x,labels=labels,explode=myexplode)
# Out:
# ([<matplotlib.patches.Wedge at 0x7f915c8e2450>,
# ...
#  [Text(1.1490666267904759, 0.9641814596829565, 'A'),
#   Text(-0.6044599917942917, 0.9190365163148008, 'C'),
#   Text(-1.4203292321049439, -0.9341653346320342, 'B'),
#   Text(0.7070662631386209, -0.8426489776479805, 'E')])

# %%
x=np.array([12,13,14,15])
labels=(["A","C","B","E"])
myexplode=[0.4,0,0.6,0]
plt.pie(x,labels=labels,explode=myexplode,shadow=True)
# Out:
# ([<matplotlib.patches.Wedge at 0x7f915cae2d50>,
# ...
#  [Text(1.1490666267904759, 0.9641814596829565, 'A'),
#   Text(-0.6044599917942917, 0.9190365163148008, 'C'),
#   Text(-1.4203292321049439, -0.9341653346320342, 'B'),
#   Text(0.7070662631386209, -0.8426489776479805, 'E')])
